# %%
import pandas as pd
import numpy as np

# %%
district_lep = pd.read_excel("data/district_lep_1718.xlsx")

# %%
cmsd_lep = district_lep.loc[district_lep["District IRN"] == 43786]

# %%
cmsd_lep
# Out:
#     District IRN        District Name Student Group  \
# 62         43786  Cleveland Municipal           LEP
# 63         43786  Cleveland Municipal        NonLEP
#
#    Read 3rd Grade 2017-2018 % Proficient or above  \
# 62                                           39.3
# 63                                           36.1
#
#    Math 3rd Grade 2017-2018 % Proficient or above  \
# 62                                           49.7
# 63                                           40.1
#
#    Read 4th Grade 2017-2018 % Proficient or above  \
# 62                                           36.5
# 63                                           37.0
#
#    Math 4th Grade 2017-2018 % Proficient or above  \
# 62                                           49.3
# 63                                           41.9
#
#    Read 5th Grade 2017-2018 % Proficient or above  \
# 62                                           36.9
# 63                                           38.2
#
# ...

# %%
lep_bldg = pd.read_excel("data/bldg_lep_1718.xlsx")

# %%
# filter for the three schools being studied
bldg_irns = [729, 24687, 32060]
lep_3filter = lep_bldg[lep_bldg['Building IRN'].isin(bldg_irns)]

# %%
lep_3filter
# Out:
#       Building IRN            Building Name  District IRN    Student Group  \
# 143            729         Andrew J Rickoff         43786  English Learner
# 1824         24687             Miles School         43786  English Learner
# 2233         32060  Robert H Jamison School         43786  English Learner
#
#      ELA 3rd Grade 2017-2018 % Proficient or above  \
# 143                                             NC
# 1824                                            NC
# 2233                                            NC
#
#      Math 3rd Grade 2017-2018 % Proficient or above  \
# 143                                              NC
# 1824                                             NC
# 2233                                             NC
#
#      ELA 4th Grade 2017-2018 % Proficient or above  \
# 143                                             NC
# 1824                                            NC
# 2233                                            NC
#
# ...
