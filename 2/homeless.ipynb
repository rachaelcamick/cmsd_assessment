# %%
import pandas as pd
import numpy as np

# %%
homeless_file = pd.read_excel("data/building_homeless_1718.xlsx")

# %%
homeless_file.head()
# Out:
#    Building IRN              Building Name  District IRN  \
# 0            59      Ada Elementary School         45187
# 1            67            Ada High School         45187
# 2            83     Sandusky Middle School         44743
# 3           102       Meigs Primary School         48520
# 4           105  Meigs Intermediate School         48520
#
#           District Name  County     Region Open/Closed Status as of 09/18/18  \
# 0  Ada Exempted Village  Hardin   Region 6                              Open
# 1  Ada Exempted Village  Hardin   Region 6                              Open
# 2         Sandusky City    Erie   Region 2                              Open
# 3           Meigs Local   Meigs  Region 16                              Open
# 4           Meigs Local   Meigs  Region 16                              Open
#
#          School Type Student Group  \
# 0  Elementary School      Homeless
# 1        High School      Homeless
# 2      Middle School      Homeless
# ...

# %%
bldg_irns = [729, 24687, 32060]
three_schools = homeless_file[homeless_file['Building IRN'].isin(bldg_irns)]

# %%
three_schools
# Out:
#       Building IRN            Building Name  District IRN  \
# 143            729         Andrew J Rickoff         43786
# 1824         24687             Miles School         43786
# 2233         32060  Robert H Jamison School         43786
#
#             District Name    County    Region  \
# 143   Cleveland Municipal  Cuyahoga  Region 3
# 1824  Cleveland Municipal  Cuyahoga  Region 3
# 2233  Cleveland Municipal  Cuyahoga  Region 3
#
#      Open/Closed Status as of 09/18/18        School Type Student Group  \
# 143                               Open  Elementary School      Homeless
# 1824                              Open  Elementary School      Homeless
# 2233                              Open  Elementary School      Homeless
#
#      ELA 3rd Grade 2017-2018 % Proficient or above    ...     \
# 143                                             NC    ...
# 1824                                            NC    ...
# 2233                                            NC    ...
#
# ...

# %%
#replace all NC with NaNs so I can manipulate

three_schools.replace('NC', np.nan, inplace=True)
# Out:
# C:\Users\Rachael C. Amick\anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py:3798: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)

# %%
#drop all columns with all NA values

three_schools.dropna(axis=1, how='all', inplace=True)
# Out:
# C:\Users\Rachael C. Amick\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
three_schools.drop(columns=['District IRN', 'District Name'], inplace=True)
# Out:
# C:\Users\Rachael C. Amick\anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
three_schools
# Out:
#       Building IRN            Building Name    County    Region  \
# 143            729         Andrew J Rickoff  Cuyahoga  Region 3
# 1824         24687             Miles School  Cuyahoga  Region 3
# 2233         32060  Robert H Jamison School  Cuyahoga  Region 3
#
#      Open/Closed Status as of 09/18/18        School Type Student Group  \
# 143                               Open  Elementary School      Homeless
# 1824                              Open  Elementary School      Homeless
# 2233                              Open  Elementary School      Homeless
#
#       Attendance Rate 2017-2018  Enrollment 2017-2018  \
# 143                        85.2                    35
# 1824                       90.2                    34
# 2233                       91.0                    12
#
#      Percent of Total Enrollment 2017-2018
# 143                                    7.9
# 1824                                   8.1
# 2233                                   3.3
