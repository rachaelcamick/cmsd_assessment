# %%
import pandas as pd

# %%
cmsd_enrollment = pd.read_csv("data/single_dataset/single_cmsd_dataset.csv")

# %%
# filter for the three schools being studied
bldg_irns = [729, 24687, 32060]
three_schools = cmsd_enrollment[cmsd_enrollment['Building_IRN'].isin(bldg_irns)]

# %%
three_schools
# Out:
#     Unnamed: 0  Building_IRN            Building_Name  District_IRN  \
# 3            3           729         Andrew J Rickoff       43786.0
# 81          81         24687             Miles School       43786.0
# 93          93         32060  Robert H Jamison School       43786.0
#
#     performanceIndexPercent_2015_2016  performanceIndexPercent_2016_2017  \
# 3                              44.327                             47.131
# 81                             42.455                             49.554
# 93                             39.832                             44.587
#
#     performanceIndexPercent_2017_2018  Enrollment_Total_1516  \
# 3                              49.875                  406.0
# 81                             52.526                  359.0
# 93                             43.229                  324.0
#
#     Enrollment_Total_1617  Enrollment_Total_1718  \
# 3                   386.0                  442.0
# ...

# %%
educators_1718 = pd.read_excel("data/1718_educator.xlsx")

# %%
educators_reduced = educators_1718[educators_1718['Building IRN'].isin(bldg_irns)]

# %%
educators_reduced
# Out:
#      District IRN        District Name  Building IRN            Building Name  \
# 575         43786  Cleveland Municipal           729         Andrew J Rickoff
# 655         43786  Cleveland Municipal         24687             Miles School
# 672         43786  Cleveland Municipal         32060  Robert H Jamison School
#
#      Number of Lead/Senior Professional Teachers FTE Full Time Tchrs  \
# 575                                            0                  26
# 655                                            1                  24
# 672                                            1                  22
#
#     Tchr FTE at least Bachelors Pct Tchr FTE at least Bachelors  \
# 575                          26                           100.0
# 655                          24                           100.0
# 672                          22                           100.0
#
#     Tchr FTE at least Masters Pct Tchr FTE at least Masters  \
# ...
