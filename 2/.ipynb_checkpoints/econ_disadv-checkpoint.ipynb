# %%
import pandas as pd 
import numpy as np

# %%
econ_dis = pd.read_excel("data/econ_disadvantaged.xlsx")

# %%
# filter for the three schools being studied
bldg_irns = [729, 24687, 32060]
reduced_econdis = econ_dis[econ_dis['Building IRN'].isin(bldg_irns)]

# %%
#replace all NC with NaNs so I can manipulate

reduced_econdis.replace('NC', np.nan, inplace=True)
# Out:
# C:\Users\Rachael C. Amick\anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py:3798: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)

# %%
#drop all columns with all NA values

reduced_econdis.dropna(axis=1, how='all', inplace=True)
# Out:
# C:\Users\Rachael C. Amick\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
reduced_econdis
# Out:
#       Building IRN            Building Name     Student Group  \
# 286            729         Andrew J Rickoff     Disadvantaged
# 287            729         Andrew J Rickoff  NonDisadvantaged
# 3648         24687             Miles School     Disadvantaged
# 3649         24687             Miles School  NonDisadvantaged
# 4466         32060  Robert H Jamison School     Disadvantaged
# 4467         32060  Robert H Jamison School  NonDisadvantaged
#
#       ELA 3rd Grade 2017-2018 % Proficient or above  \
# 286                                             5.5
# 287                                             NaN
# 3648                                           22.6
# 3649                                            NaN
# 4466                                           12.2
# 4467                                            NaN
#
#       Math 3rd Grade 2017-2018 % Proficient or above  \
# 286                                             11.3
# ...

# %%
#want to compare with district economically disadvantaged students

# %%
district_econ_dis = pd.read_excel("data/district_econdis_1718.xlsx")

# %%
cmsd_econdis = district_econ_dis.loc[district_econ_dis["District IRN"] == 43786]

# %%
cmsd_econdis
# Out:
#     District IRN        District Name    County    Region     Student Group  \
# 62         43786  Cleveland Municipal  Cuyahoga  Region 3     Disadvantaged
# 63         43786  Cleveland Municipal  Cuyahoga  Region 3  NonDisadvantaged
#
#    Read 3rd Grade 2017-2018 % Proficient or above  \
# 62                                           35.4
# 63                                           87.3
#
#    Math 3rd Grade 2017-2018 % Proficient or above  \
# 62                                           40.2
# 63                                           65.5
#
#    Read 4th Grade 2017-2018 % Proficient or above  \
# 62                                           36.0
# 63                                           85.2
#
#    Math 4th Grade 2017-2018 % Proficient or above  \
# 62                                           41.5
# 63                                           85.5
#
#    Read 5th Grade 2017-2018 % Proficient or above    ...     \
# ...

# %%
#replace all NC with NaNs so I can manipulate

cmsd_econdis.replace('NC', np.nan, inplace=True)

#drop all columns with all NA values

cmsd_econdis.dropna(axis=1, how='all', inplace=True)
# Out:
# C:\Users\Rachael C. Amick\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
cmsd_econdis
# Out:
#     District IRN        District Name    County    Region     Student Group  \
# 62         43786  Cleveland Municipal  Cuyahoga  Region 3     Disadvantaged
# 63         43786  Cleveland Municipal  Cuyahoga  Region 3  NonDisadvantaged
#
#    Read 3rd Grade 2017-2018 % Proficient or above  \
# 62                                           35.4
# 63                                           87.3
#
#    Math 3rd Grade 2017-2018 % Proficient or above  \
# 62                                           40.2
# 63                                           65.5
#
#    Read 4th Grade 2017-2018 % Proficient or above  \
# 62                                           36.0
# 63                                           85.2
#
#    Math 4th Grade 2017-2018 % Proficient or above  \
# 62                                           41.5
# 63                                           85.5
#
#    Read 5th Grade 2017-2018 % Proficient or above          ...           \
# ...

# %%
cmsd_econdis.columns.values
# Out:
# array(['District IRN', 'District Name', 'County', 'Region',
#        'Student Group', 'Read 3rd Grade 2017-2018 % Proficient or above',
#        'Math 3rd Grade 2017-2018 % Proficient or above',
#        'Read 4th Grade 2017-2018 % Proficient or above',
#        'Math 4th Grade 2017-2018 % Proficient or above',
#        'Read 5th Grade 2017-2018 % Proficient or above',
#        'Math 5th Grade 2017-2018 % Proficient or above',
#        'Science 5th Grade 2017-2018 % Proficient or above',
#        'Read 6th Grade 2017-2018 % Proficient or above',
#        'Math 6th Grade 2017-2018 % Proficient or above',
#        'Read 7th Grade 2017-2018 % Proficient or above',
#        'Math 7th Grade 2017-2018% Proficient or above',
#        'Read 8th Grade 2017-2018 % Proficient or above',
#        'Math 8th Grade 2017-2018 % Proficient or above',
#        'Science 8th Grade 2017-2018 % Proficient or above',
#        'History End of Course 2017-2018 % Proficient or above',
# ...

# %%
# drop columns that aren't relevant to elementary schools 

cmsd_econdis.drop(columns=['County', 'Region', 'History End of Course 2017-2018 % Proficient or above', 'Government End of Course 2017-2018 % Proficient or above', 'English Language Arts I End of Course 2017-2018 % Proficient or', 'English Language Arts II End of Course 2017-2018 % Proficient or', 'Algebra I End of Course 2017-2018 % Proficient or above', 'Geometry End of Course 2017-2018 % Proficient or above', 'Biology End of Course 2017-2018 % Proficient or above', '4-Year Longitudinal Graduation Rate - Class of 2017', '5-Year Longitudinal Graduation Rate - Class of 2016'], inplace=True)
# Out:
# C:\Users\Rachael C. Amick\anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
cmsd_econdis
# Out:
#     District IRN        District Name     Student Group  \
# 62         43786  Cleveland Municipal     Disadvantaged
# 63         43786  Cleveland Municipal  NonDisadvantaged
#
#    Read 3rd Grade 2017-2018 % Proficient or above  \
# 62                                           35.4
# 63                                           87.3
#
#    Math 3rd Grade 2017-2018 % Proficient or above  \
# 62                                           40.2
# 63                                           65.5
#
#    Read 4th Grade 2017-2018 % Proficient or above  \
# 62                                           36.0
# 63                                           85.2
#
#    Math 4th Grade 2017-2018 % Proficient or above  \
# 62                                           41.5
# 63                                           85.5
#
#    Read 5th Grade 2017-2018 % Proficient or above  \
# 62                                           37.0
# 63                                          >95.0
#
# ...
