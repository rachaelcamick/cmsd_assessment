# %%
import pandas as pd
import numpy as np

# %%
disabled_group = pd.read_excel("data/bldg_disabled_1718.xlsx")

# %%
disabled_group.head()
# Out:
#    Building IRN           Building Name  District IRN         District Name  \
# 0            59   Ada Elementary School         45187  Ada Exempted Village
# 1            59   Ada Elementary School         45187  Ada Exempted Village
# 2            67         Ada High School         45187  Ada Exempted Village
# 3            67         Ada High School         45187  Ada Exempted Village
# 4            83  Sandusky Middle School         44743         Sandusky City
#
#   Student Group ELA 3rd Grade 2017-2018 % Proficient or above  \
# 0      Disabled                                            NC
# 1   NonDisabled                                          87.3
# 2      Disabled                                            NC
# 3   NonDisabled                                            NC
# 4      Disabled                                            NC
#
#   Math 3rd Grade 2017-2018 % Proficient or above  \
# 0                                             NC
# ...

# %%
# filter for the three schools being studied
bldg_irns = [729, 24687, 32060]
disabled_3filter = disabled_group[disabled_group['Building IRN'].isin(bldg_irns)]

# %%
disabled_3filter
# Out:
#       Building IRN            Building Name  District IRN  \
# 286            729         Andrew J Rickoff         43786
# 287            729         Andrew J Rickoff         43786
# 3648         24687             Miles School         43786
# 3649         24687             Miles School         43786
# 4466         32060  Robert H Jamison School         43786
# 4467         32060  Robert H Jamison School         43786
#
#             District Name Student Group  \
# 286   Cleveland Municipal      Disabled
# 287   Cleveland Municipal   NonDisabled
# 3648  Cleveland Municipal      Disabled
# 3649  Cleveland Municipal   NonDisabled
# 4466  Cleveland Municipal      Disabled
# 4467  Cleveland Municipal   NonDisabled
#
#      ELA 3rd Grade 2017-2018 % Proficient or above  \
# 286                                             NC
# 287                                            6.8
# 3648                                           6.3
# 3649                                          29.7
# ...

# %%
#replace all NC with NaNs so I can manipulate

disabled_3filter.replace('NC', np.nan, inplace=True)
# Out:
# C:\Users\Rachael C. Amick\anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py:3798: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)

# %%
#drop all columns with all NA values

disabled_3filter.dropna(axis=1, how='all', inplace=True)
# Out:
# C:\Users\Rachael C. Amick\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
disabled_3filter
# Out:
#       Building IRN            Building Name  District IRN  \
# 286            729         Andrew J Rickoff         43786
# 287            729         Andrew J Rickoff         43786
# 3648         24687             Miles School         43786
# 3649         24687             Miles School         43786
# 4466         32060  Robert H Jamison School         43786
# 4467         32060  Robert H Jamison School         43786
#
#             District Name Student Group  \
# 286   Cleveland Municipal      Disabled
# 287   Cleveland Municipal   NonDisabled
# 3648  Cleveland Municipal      Disabled
# 3649  Cleveland Municipal   NonDisabled
# 4466  Cleveland Municipal      Disabled
# 4467  Cleveland Municipal   NonDisabled
#
#       ELA 3rd Grade 2017-2018 % Proficient or above  \
# 286                                             NaN
# 287                                             6.8
# 3648                                            6.3
# 3649                                           29.7
# ...

# %%
disabled_3filter.drop(columns=['District IRN', 'District Name'], inplace=True)
# Out:
# C:\Users\Rachael C. Amick\anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
disabled_3filter
# Out:
#       Building IRN            Building Name Student Group  \
# 286            729         Andrew J Rickoff      Disabled
# 287            729         Andrew J Rickoff   NonDisabled
# 3648         24687             Miles School      Disabled
# 3649         24687             Miles School   NonDisabled
# 4466         32060  Robert H Jamison School      Disabled
# 4467         32060  Robert H Jamison School   NonDisabled
#
#       ELA 3rd Grade 2017-2018 % Proficient or above  \
# 286                                             NaN
# 287                                             6.8
# 3648                                            6.3
# 3649                                           29.7
# 4466                                           16.7
# 4467                                           10.3
#
#       Math 3rd Grade 2017-2018 % Proficient or above  \
# 286                                             10.0
# 287                                             11.6
# ...

# %%
#disabled students are underperforming by a large margin at Miles

#make graphs to show comparisons

#first split the dataframe by school

# rickoff = disabled_3filter.loc[disabled_3filter['Building IRN'] == 729]
# miles = disabled_3filter.loc[disabled_3filter['Building IRN'] == 24687]
# jamison = disabled_3filter.loc[disabled_3filter['Building IRN'] == 32060]

#=============================================================================

# %%
district_disabled = pd.read_excel('data/dist_disabled_1718.xlsx')

# %%
cmsd_disabled = district_disabled.loc[district_disabled["District IRN"] == 43786]

# %%
#replace all NC with NaNs so I can manipulate

cmsd_disabled.replace('NC', np.nan, inplace=True)

#drop all columns with all NA values

cmsd_disabled.dropna(axis=1, how='all', inplace=True)
# Out:
# C:\Users\Rachael C. Amick\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
cmsd_disabled
# Out:
#     District IRN        District Name Student Group  \
# 62         43786  Cleveland Municipal      Disabled
# 63         43786  Cleveland Municipal   NonDisabled
#
#    Read 3rd Grade 2017-2018 % Proficient or above  \
# 62                                           21.5
# 63                                           40.3
#
#    Math 3rd Grade 2017-2018 % Proficient or above  \
# 62                                           24.8
# 63                                           45.0
#
#    Read 4th Grade 2017-2018 % Proficient or above  \
# 62                                           23.6
# 63                                           40.7
#
#    Math 4th Grade 2017-2018 % Proficient or above  \
# 62                                           26.3
# 63                                           46.9
#
#    Read 5th Grade 2017-2018 % Proficient or above  \
# 62                                           25.8
# 63                                           41.8
#
# ...
